# %%
import pandas as pd
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vincentvaseghi/us-cities-housing-market-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/sodamna/.cache/kagglehub/datasets/vincentvaseghi/us-cities-housing-market-data/versions/30

# %%
files = os.listdir(path)
print("Files in dataset directory:", files)

data = pd.read_csv(os.path.join(path, 'city_market_tracker.tsv000'), sep='\t')
data.head()
# Out:
# Files in dataset directory: ['city_market_tracker.tsv000']
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2015-09-01  2015-09-30               30       place               6
# 1   2022-09-01  2022-09-30               30       place               6
# 2   2016-06-01  2016-06-30               30       place               6
# 3   2023-05-01  2023-05-31               30       place               6
# 4   2021-02-01  2021-02-28               30       place               6
#
#    table_id is_seasonally_adjusted            region          city  \
# 0      7874                      f    Golf Manor, OH    Golf Manor
# 1     13198                      f    Okeechobee, FL    Okeechobee
# 2     36710                      f  Amherst Town, MA  Amherst Town
# 3     29751                      f          Stow, MA          Stow
# 4     23772                      f        Kearns, UT        Kearns
#
#            state  ... sold_above_list_yoy price_drops  price_drops_mom  \
# 0           Ohio  ...            0.500000    0.230769         0.030769
# 1        Florida  ...           -0.168831    0.268293        -0.017422
# 2  Massachusetts  ...            0.000000         NaN              NaN
# 3  Massachusetts  ...           -0.400000    0.214286         0.014286
# 4           Utah  ...                 NaN         NaN              NaN
#
#    price_drops_yoy  off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0              NaN                 0.166667                     0.166667
# 1         0.062410                 0.000000                    -0.166667
# 2              NaN                 0.000000                     0.000000
# 3         0.071429                 0.636364                     0.064935
# 4              NaN                 0.000000                          NaN
#
#    off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                     0.166667       Cincinnati, OH
# 1                    -0.375000       Okeechobee, FL
# 2                     0.000000      Springfield, MA
# 3                    -0.063636           Boston, MA
# 4                          NaN   Salt Lake City, UT
#
#    parent_metro_region_metro_code         last_updated
# 0                           17140  2024-10-16 14:24:52
# 1                           36380  2024-10-16 14:24:52
# 2                           44140  2024-10-16 14:24:52
# 3                           14454  2024-10-16 14:24:52
# 4                           41620  2024-10-16 14:24:52
#
# [5 rows x 58 columns]

# %%
len(data)
data.to_csv('house pricing data.csv')

# %%
data.median_ppsf.mean()
# Out:
# 191.71933955683443

# %%
data.describe
